# %%
import financialtool

# %% [markdown]
# # Yield Curve

# %%
rates_data, tenor_list, tenor_in_days = financialtool.rates.get_yield_curve(country='US', dates=['MTD','WTD', 'QTD'], plot=True)

# ax = rates_data.plot(title='US Treasury Yield Curve')
# _ = ax.set_xticks(tenor_in_days)
# x_labels = tenor_list.copy()
# x_labels[1] = None
# x_labels[2] = None
# _ = ax.set_xticklabels(x_labels)
